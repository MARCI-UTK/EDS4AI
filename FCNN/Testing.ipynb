# %%
from Trial import Trial

# %%
tr_l, tr_ac, te_l, te_ac = Trial(deficit='similarity', subset_size=0.5, deficit_duration=3, post_duration=3, save_dir='a')
# Out:
# quantiles_test length: 50000
# subset: [    1     2     3 ... 49996 49997 49998]
# Using device: cuda:3
# Epoch [1/3], LR: [0.01], Train Loss: 1.0413, Train Acc: 24.78%, Test Loss: 1.8216, Test Acc: 32.98%
# Epoch [2/3], LR: [0.01], Train Loss: 0.8108, Train Acc: 38.39%, Test Loss: 1.5872, Test Acc: 40.35%
# Epoch [3/3], LR: [0.01], Train Loss: 0.6625, Train Acc: 51.33%, Test Loss: 1.8613, Test Acc: 41.64%
# Epoch [4/3], LR: [0.01], Train Loss: 0.5421, Train Acc: 61.18%, Test Loss: 1.3029, Test Acc: 57.41%
# Epoch [5/3], LR: [0.01], Train Loss: 0.4547, Train Acc: 67.95%, Test Loss: 1.2252, Test Acc: 59.20%
# Epoch [6/3], LR: [0.01], Train Loss: 0.3888, Train Acc: 72.89%, Test Loss: 1.4771, Test Acc: 57.65%
# Training Finished!

# %%
import matplotlib.pyplot as plt

num_epochs = 6

train_loss_list = tr_l
train_acc_list = tr_ac 
test_loss_list = te_l
test_acc_list = te_ac


plt.figure(figsize=(10,5))
plt.plot(range(1, num_epochs+1), train_loss_list, label='Train Loss')
plt.plot(range(1, num_epochs+1), test_loss_list, label='Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Test Loss Over Epochs')
plt.legend()
plt.grid()
plt.show()

# Plot accuracy curves
plt.figure(figsize=(10,5))
plt.plot(range(1, num_epochs+1), train_acc_list, label='Train Accuracy')
plt.plot(range(1, num_epochs+1), test_acc_list, label='Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.title('Training and Test Accuracy Over Epochs')
plt.legend()
plt.grid()
plt.show()

# Print final test accuracy
print(f"Final Test Accuracy: {test_acc_list[-1]:.2f}%")
# Out:
# Final Test Accuracy: 57.65%
