# %%
from Trial import Trial

# %%
#tr_l, tr_ac, te_l, te_ac = Trial(deficit='similarity', subset_size=0.1, deficit_duration=3, post_duration=1, save_dir='a')

# %%
#from ViewExperiment import ViewExperiment

#ViewExperiment(4, tr_l, tr_ac, te_l, te_ac)

# %%
from ViewExperiment import ViewExperiment

ViewExperiment('disimilarity', 5, 0.1)
# Out:
# Final Test Accuracy: 35.47%
